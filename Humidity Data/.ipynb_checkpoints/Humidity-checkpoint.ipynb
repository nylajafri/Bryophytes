# %%
##Reference 
#meteostat

# %%
pip install meteostat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Import Meteostat library and dependencies
from datetime import datetime
#from meteostat import Monthly
from meteostat import Hourly
import pandas as pd

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31, 23, 59)

# Get hourly data
data = Hourly('72219', start, end)
data = data.fetch()

# Print DataFrame
#pd.set_option("max_rows", None)
#pd.set_option("display.max_rows", None)
#print(data)

# Print DataFrame
dataresult = pd.DataFrame(data)
pd.set_option("display.max_columns", None)
print(dataresult)
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 00:00:00   0.6  -5.6  63.0   NaN   NaN  340.0  18.4   NaN  1024.6
# 2018-01-01 01:00:00  -1.1  -6.6  66.0   0.0   NaN  320.0  16.6   NaN  1025.4
# 2018-01-01 02:00:00  -1.1  -9.5  53.0   0.0   NaN  330.0  22.3   NaN  1025.8
# 2018-01-01 03:00:00  -1.1 -10.0  51.0   0.0   NaN  330.0  25.9   NaN  1025.6
# 2018-01-01 04:00:00  -1.7 -10.5  51.0   0.0   NaN  340.0  18.4   NaN  1026.1
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2018-12-31 19:00:00  20.0  17.2  84.0   0.0   NaN  200.0  18.4   NaN  1016.5
# 2018-12-31 20:00:00  21.1  16.7  76.0   0.0   NaN  190.0  22.3   NaN  1015.8
# 2018-12-31 21:00:00  21.1  16.1  73.0   0.0   NaN  180.0  27.7   NaN  1014.7
# 2018-12-31 22:00:00  21.1  15.0  68.0   0.0   NaN  190.0  27.7   NaN  1015.7
# 2018-12-31 23:00:00  20.0  15.0  73.0   0.0   NaN  180.0  20.5   NaN  1015.6
#
#                      tsun  coco
# ...

# %%
# Import Meteostat library and dependencies (Trial)
from datetime import datetime
#from meteostat import Monthly
from meteostat import Hourly
import pandas as pd

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31, 23, 59)

# Get hourly data
data = Hourly('72219', start, end)
data = data.fetch()

# Print DataFrame
pd.set_option("display.max_rows", None)
print(data)
# Out:
#                      temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 00:00:00   0.6  -5.6   63.0   NaN   NaN  340.0  18.4   NaN  1024.6
# 2018-01-01 01:00:00  -1.1  -6.6   66.0   0.0   NaN  320.0  16.6   NaN  1025.4
# 2018-01-01 02:00:00  -1.1  -9.5   53.0   0.0   NaN  330.0  22.3   NaN  1025.8
# 2018-01-01 03:00:00  -1.1 -10.0   51.0   0.0   NaN  330.0  25.9   NaN  1025.6
# 2018-01-01 04:00:00  -1.7 -10.5   51.0   0.0   NaN  340.0  18.4   NaN  1026.1
# 2018-01-01 05:00:00  -2.2 -10.5   53.0   0.0   NaN  330.0  25.9   NaN  1026.5
# 2018-01-01 06:00:00  -3.3 -11.8   52.0   0.0   NaN  340.0  24.1   NaN  1026.9
# 2018-01-01 07:00:00  -3.9 -12.8   50.0   0.0   NaN  320.0  27.7   NaN  1027.6
# 2018-01-01 08:00:00  -5.0 -13.8   50.0   0.0   NaN  330.0  25.9   NaN  1028.0
# 2018-01-01 09:00:00  -5.6 -14.4   50.0   0.0   NaN  330.0  22.3   NaN  1028.4
# 2018-01-01 10:00:00  -6.1 -14.4   52.0   0.0   NaN  330.0  27.7   NaN  1028.6
# ...

# %%
# Import Meteostat library and dependencies
from datetime import datetime
from meteostat import Hourly
import pandas as pd

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31, 23, 59)

# Get hourly data
data = Hourly('72219', start, end)
data = data.fetch()

# Print DataFrame
dataresult = pd.DataFrame(data)
pd.set_option("display.max_columns", None)
print(dataresult)
# Out:
#                      temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 00:00:00   0.6  -5.6   63.0   NaN   NaN  340.0  18.4   NaN  1024.6
# 2018-01-01 01:00:00  -1.1  -6.6   66.0   0.0   NaN  320.0  16.6   NaN  1025.4
# 2018-01-01 02:00:00  -1.1  -9.5   53.0   0.0   NaN  330.0  22.3   NaN  1025.8
# 2018-01-01 03:00:00  -1.1 -10.0   51.0   0.0   NaN  330.0  25.9   NaN  1025.6
# 2018-01-01 04:00:00  -1.7 -10.5   51.0   0.0   NaN  340.0  18.4   NaN  1026.1
# 2018-01-01 05:00:00  -2.2 -10.5   53.0   0.0   NaN  330.0  25.9   NaN  1026.5
# 2018-01-01 06:00:00  -3.3 -11.8   52.0   0.0   NaN  340.0  24.1   NaN  1026.9
# 2018-01-01 07:00:00  -3.9 -12.8   50.0   0.0   NaN  320.0  27.7   NaN  1027.6
# 2018-01-01 08:00:00  -5.0 -13.8   50.0   0.0   NaN  330.0  25.9   NaN  1028.0
# 2018-01-01 09:00:00  -5.6 -14.4   50.0   0.0   NaN  330.0  22.3   NaN  1028.4
# 2018-01-01 10:00:00  -6.1 -14.4   52.0   0.0   NaN  330.0  27.7   NaN  1028.6
# ...

# %%
#final 
# Import Meteostat library and dependencies (Trial)
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Hourly
import pandas as pd

# Set time period
start = datetime(2019, 1, 1)
end = datetime(2019, 12, 31, 23, 59)

#Location
gpspoint = Point(49.2497, -123.1193, 70)

# Get hourly data
data = Hourly(gpspoint, start, end)
data = data.fetch()

# Print DataFrame
pd.set_option('display.max_columns', 6)
pd.set_option("display.max_rows", None)
print(data)

import csv 

def csvOutput(self, output: list):
    if(self.fileName != ''):
        with open(self.fileName, 'a', newline='') as csvFile:
            writer = csv.writer(csvFile)
            writer.writerow(output)
        csvFile.close()
# Out:
#                      temp  dwpt   rhum  ...    pres  tsun  coco
# time                                    ...
# 2019-01-01 00:00:00   4.2  -1.6   66.0  ...  1032.8   NaN   3.0
# 2019-01-01 01:00:00   3.9  -0.1   75.0  ...  1032.5   NaN   3.0
# 2019-01-01 02:00:00   3.1  -0.4   78.0  ...  1032.8   NaN   3.0
# 2019-01-01 03:00:00   3.9   0.8   80.0  ...  1032.4   NaN   4.0
# 2019-01-01 04:00:00   3.7   0.7   81.0  ...  1031.6   NaN   3.0
# 2019-01-01 05:00:00   3.3   0.7   83.0  ...  1031.8   NaN   3.0
# 2019-01-01 06:00:00   3.3   0.5   82.0  ...  1031.6   NaN   4.0
# 2019-01-01 07:00:00   3.3   0.7   83.0  ...  1031.5   NaN   3.0
# 2019-01-01 08:00:00   3.2  -0.8   75.0  ...  1031.6   NaN   3.0
# 2019-01-01 09:00:00   3.3   0.3   81.0  ...  1031.3   NaN   4.0
# 2019-01-01 10:00:00   3.0   0.9   86.0  ...  1031.6   NaN   4.0
# 2019-01-01 11:00:00   2.3  -0.3   83.0  ...  1031.7   NaN   4.0
# 2019-01-01 12:00:00   3.0   0.6   84.0  ...  1031.3   NaN   3.0
# ...

# %%
 import csv 
    
    def csvOutput(self, output: list):
        if(self.fileName != ''):
            with open(self.fileName, 'a', newline='') as csvFile:
                writer = csv.writer(csvFile)
                writer.writerow(output)
            csvFile.close()
