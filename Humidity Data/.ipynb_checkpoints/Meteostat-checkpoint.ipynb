# %%
pip install meteostat
# Out:
# Collecting meteostatNote: you may need to restart the kernel to use updated packages.
#
#   Downloading meteostat-1.6.5-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\nylaj\anaconda3\lib\site-packages (from meteostat) (1.5.3)
# Requirement already satisfied: numpy in c:\users\nylaj\anaconda3\lib\site-packages (from meteostat) (1.23.5)
# Requirement already satisfied: pytz in c:\users\nylaj\anaconda3\lib\site-packages (from meteostat) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nylaj\anaconda3\lib\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nylaj\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.5

# %%
pip install -U matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nylaj\anaconda3\lib\site-packages (3.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nylaj\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: six>=1.5 in c:\users\nylaj\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.0
#     Uninstalling matplotlib-3.7.0:
#       Successfully uninstalled matplotlib-3.7.0
# Successfully installed matplotlib-3.7.1

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2022, 5, 15)
end = datetime(2023, 5, 15)

# Create Point for Vancouver, BC
vancouver = Point(49.2497, -123.1193, 70)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

#Print average humidity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 22
#      19 plt.show()
#      21 #Print average temperature
# ---> 22 print(y=['tavg'])
#
# TypeError: 'y' is an invalid keyword argument for print()

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Stations, Monthly

# Set time period
start = datetime(2000, 1, 1)
end = datetime(2018, 12, 31)

# Get Monthly data
data = Monthly('10637', start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Normals

# Get Normals data
data = Normals('10637', 1961, 1990)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
# Import Meteostat library and dependencies
from datetime import datetime
from meteostat import Hourly
import pandas as pd

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31, 23, 59)

# Get hourly data
data = Hourly('72219', start, end)
data = data.fetch()

# Print DataFrame
dataresult = pd.DataFrame(data)
pd.set_option("display.max_columns", None)
print(dataresult)
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 00:00:00   0.6  -5.6  63.0   NaN   NaN  340.0  18.4   NaN  1024.6
# 2018-01-01 01:00:00  -1.1  -6.6  66.0   0.0   NaN  320.0  16.6   NaN  1025.4
# 2018-01-01 02:00:00  -1.1  -9.5  53.0   0.0   NaN  330.0  22.3   NaN  1025.8
# 2018-01-01 03:00:00  -1.1 -10.0  51.0   0.0   NaN  330.0  25.9   NaN  1025.6
# 2018-01-01 04:00:00  -1.7 -10.5  51.0   0.0   NaN  340.0  18.4   NaN  1026.1
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2018-12-31 19:00:00  20.0  17.2  84.0   0.0   NaN  200.0  18.4   NaN  1016.5
# 2018-12-31 20:00:00  21.1  16.7  76.0   0.0   NaN  190.0  22.3   NaN  1015.8
# 2018-12-31 21:00:00  21.1  16.1  73.0   0.0   NaN  180.0  27.7   NaN  1014.7
# 2018-12-31 22:00:00  21.1  15.0  68.0   0.0   NaN  190.0  27.7   NaN  1015.7
# 2018-12-31 23:00:00  20.0  15.0  73.0   0.0   NaN  180.0  20.5   NaN  1015.6
#
#                      tsun  coco
# time
# 2018-01-01 00:00:00   NaN   NaN
# 2018-01-01 01:00:00   NaN   NaN
# 2018-01-01 02:00:00   NaN   NaN
# 2018-01-01 03:00:00   NaN   NaN
# 2018-01-01 04:00:00   NaN   NaN
# ...                   ...   ...
# 2018-12-31 19:00:00   NaN   4.0
# 2018-12-31 20:00:00   NaN   4.0
# 2018-12-31 21:00:00   NaN   4.0
# 2018-12-31 22:00:00   NaN   7.0
# 2018-12-31 23:00:00   NaN   7.0
#
# [8760 rows x 11 columns]
